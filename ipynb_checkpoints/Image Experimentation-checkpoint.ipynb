# %%
import requests
url = "http://images.dpchallenge.com/images_challenge/0-999/521/120/Copyrighted_Image_Reuse_Prohibited_359270.jpg"
r = requests.get(url, allow_redirects=True)
open('buffer.jpg', 'wb').write(r.content)

# %%
header = r.headers

# %%
print(r.headers.get('Content-Type'))
# Out:
# image/jpeg

# %%
r.content
# Out:
# '<html>\n<head>\n\t<title>Big City Lights by scalvert - DPChallenge</title>\n\t<link rel="styleSheet" type="text/css" href="/include/styles.css" />\n\t<meta name="keywords" Content="photography contest, digital photography, digital cameras, contest, digital photos, photo contest, digital imaging, challenge, cameras, photography tutorials, photography forums, photography discussion, langdon oliver, andrew ungvarsky" />\n\t<meta name="description" Content="Weekly digital photography contest site, featuring active forums, tutorials, photographer profiles, and more.  Enter and/or vote -- fun learning for ALL skill levels." />\n\t<script type="text/javascript" src="/include/jquery-1.7.1.min.js"></script>\n\t<script type="text/javascript" src="/include/main.js"></script>\n</head>\n<body class="textsm" style="background: #DDDDDD url(\'/images/back.gif\') repeat-y;" leftmargin="0" topmargin="0" marginwidth="0" marginheight="0" onload="overlay();">\n\n\t\t<script type="text/javascript">functi
# ...
